# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
y
# Out:
# array([  0.  ,   0.25,   1.  ,   2.25,   4.  ,   6.25,   9.  ,  12.25,
#         16.  ,  20.25,  25.  ])

# %% [markdown]
# Creating a Matplotlib plot

# %%
#Functional method, pass in several arguments 

plt.plot(x,y)  # shows x versus y plot
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title("Title")
# Out:
# Text(0.5,1,'Title')

# %%
# creating multi-plots on same canvas

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
# object oriented method

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel("Y Label")
axes.set_title("Set Title")
# Out:
# Text(0.5,1,'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])

axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_xlabel('X-Axis')
axes1.set_ylabel("Y-Axis")
axes1.set_title("Larger Plot")

axes2.plot(y,x)
axes2.set_xlabel('X')
axes2.set_ylabel("Y")
axes2.set_title("Smaller Plot")
# Out:
# Text(0.5,1,'Smaller Plot')

# %%
# part 2

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

#axes.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=3,ncols=3)

plt.tight_layout()

# %%
axes # axes object is just an array of matplotlib axes, list, can itterate through it.
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fcdfa73b6a0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fcdfb3bbf28>], dtype=object)

# %% [markdown]
# Subplots that you want arranged in rows and columns

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

for current_ax in axes:
    current_ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

axes[0].plot(x,y)
axes[0].set_title("First Plot")
axes[0].set_xlabel("X")
axes[0].set_ylabel("Y")

axes[1].plot(y,x)
axes[1].set_title("Second Plot")

plt.tight_layout() # should always put this; just to avoid overlapping

# %% [markdown]
# to edit markdowns like this, can use https://medium.com/ibm-data-science-experience/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed for a cheat sheet.
# > ##  __Figure Size, aspect ratio, and DPI__

# %%
fig = plt.figure(figsize =(3,2), dpi=100)

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y)

# %%
fig,axes = plt.subplots(figsize=(8,2))

axes.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))

axes[0].plot(x,y)

axes[1].plot(y,x)

plt.tight_layout()

# %%
# to save a figure

# %%
fig.savefig("my_picture.png", dpi=200) # can also use .jpeg, .jpg , ect... depending on desired file type.

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y)

ax.set_title("Title")
ax.set_xlabel('X')
ax.set_ylabel("Y")
# Out:
# Text(0,0.5,'Y')

# %%
# Legends, to tell the difference between plots

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2)
ax.plot(x,x**3)

ax.legend()
# Out:
# No handles with labels found to put in legend.

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2,label="X Squared")
ax.plot(x,x**3, label="x Cubed")

ax.legend()

# %% [markdown]
# Use this link as a reference for the legend function
#
# for example: best = 0, so you'd type "ax.legend(loc=0)".
#  upper right = 1, upper left = 2, lower left = 3, lower right = 4, right = 5,
#    center left = 6, center right = 7, lower center = 8, upper center = 9,
#                center = 10
#
#
# https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.legend

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2,label="X Squared")
ax.plot(x,x**3, label="x Cubed")

ax.legend(loc=10)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2,label="X Squared")
ax.plot(x,x**3, label="x Cubed")

ax.legend(loc=(0.1,0.1))

# %% [markdown]
# > #### Matplotlib Part 3 Video

# %% [markdown]
# # __Plot Appearance__

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "green")  # works for very basic color names as a string

# %%
# can get more detailed with color by using RGB hexcodes

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "#FF8C00") # can just google RGB Hex Codes

# %%
# Line Width

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple", linewidth=20) # 20x the standard line width

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple", linewidth=0.5) # 0.5 the standard line width

# %%
# alpha arguement for transparency

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple", lw=3, alpha=0.5) # can use lw for shorthand Line Width argument.

# %%
# Line Style

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple", lw=3, linestyle="--")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple", lw=3, ls="-.") # can use ls for shorthand Line Style argument

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple", lw=3, ls=":")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple", lw=3, ls="steps")

# %%
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
len(x)
# Out:
# 11

# %%
# to mark where 11 points occurred on plot

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple", lw=3, ls="-", marker="o") # different marker strings listen in notebook

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple", lw=3, ls="-", marker="+", markersize=20) # change the size of the markers

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple", lw=1, ls="-", marker="o", markersize=20,
       markerfacecolor="yellow",markeredgewidth=3,markeredgecolor="green") # more customizable functions

# %% [markdown]
# > ## Control over axis appearance
#
# In this section we look at controlling axis sizing properties in a matplot figure.

# %% [markdown]
# # __Plot Range__
#
# We can configure the ranges of the axes using the **set_ylim** and **set_xlim** methods in the axis object, or **axis('tight")** for automatically getting "tightly fitted" axes ranges:

# %%
# setting Y limit and X limit

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple", lw=2, ls="--")

ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0, 2)

# %% [markdown]
# # Special Plot Types
#
# There are many specialized plots we can create, such as barplots, histograms, scatter plots, and much more. Most of these type of plots we will actually create using seaborn, a statistical plotting library for Python. But here are a few examples of these type of plots:

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([ 12.,  10.,  12.,  12.,  13.,   7.,   6.,   7.,   8.,  13.]),
#  array([   6.,  105.,  204.,  303.,  402.,  501.,  600.,  699.,  798.,
#          897.,  996.]),
#  <a list of 10 Patch objects>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %% [markdown]
# ## Further reading
#
# http://www.matplotlib.org - The project web page for matplotlib.
#
# https://github.com/matplotlib/matplotlib - The source code for matplotlib.
#
# http://matplotlib.org/gallery.html - A large gallery showcaseing various types of plots that
# matplotlib can create. Highly recommended!
#
# http://www.loria.fr/~rougier/teaching/matplotlib - A good matplotlib tutorial.
#
# http://scipy-lectures.github.io/matplotlib/matplotlib.html - Another good matplotlib reference.

# %% [markdown]
# ### Most of the above is in the advanced notebook
